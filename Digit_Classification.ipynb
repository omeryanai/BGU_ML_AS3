# %% [markdown]
# # Computer Vision Neural Networks from Scratch
# ### Digit Classifiction
#
# This notebook was created jointly by Roei Zaady and Omer Yanai as part of the course "Computational Learning" of Prof. Lior Rokach, The Department of Software and Information Systems Engineering, Ben-Gurion University of the Negev.
#
# In addition, this work is based on the book "Machine Learning with PyTorch and Scikit-Learn" by Sebastian Raschka (Author), Yuxi (Hayden) Liu (Author), Vahid Mirjalili (Author), Dmytro Dzhulgakov (Foreword)
# ISBN-10: 1801819319
# ISBN-13: 978-1801819312

# %%
import sys
from sklearn.datasets import fetch_openml
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score,accuracy_score
from sklearn.model_selection import train_test_split
import numpy as np
from IPython.display import Image
# %matplotlib inline

# %% [markdown]
# ## Obtaining and preparing the MNIST dataset

# %% [markdown]
# The MNIST dataset is publicly available at http://yann.lecun.com/exdb/mnist/ and consists of the following four parts:
#
# - Training set images: train-images-idx3-ubyte.gz (9.9 MB, 47 MB unzipped, 60,000 examples)
# - Training set labels: train-labels-idx1-ubyte.gz (29 KB, 60 KB unzipped, 60,000 labels)
# - Test set images: t10k-images-idx3-ubyte.gz (1.6 MB, 7.8 MB, 10,000 examples)
# - Test set labels: t10k-labels-idx1-ubyte.gz (5 KB, 10 KB unzipped, 10,000 labels)

# %%
X, y = fetch_openml('mnist_784', version=1, return_X_y=True)
X = X.values
y = y.astype(int).values

print(X.shape)
print(y.shape)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(
# (70000, 784)
# (70000,)

# %% [markdown]
# Normalize to [-1, 1] range:

# %%
X = ((X / 255.) - .5) * 2

# %% [markdown]
# Visualize the first digit of each class:

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, sharex=True, sharey=True)
ax = ax.flatten()
for i in range(10):
    img = X[y == i][0].reshape(28, 28)
    ax[i].imshow(img, cmap='Greys')

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
plt.show()

# %% [markdown]
# Visualize 25 different versions of "7":

# %%
fig, ax = plt.subplots(nrows=5, ncols=5, sharex=True, sharey=True)
ax = ax.flatten()
for i in range(25):
    img = X[y == 7][i].reshape(28, 28)
    ax[i].imshow(img, cmap='Greys')

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
# plt.savefig('figures/11_5.png', dpi=300)
plt.show()

# %% [markdown]
# Split into training, validation, and test set:

# %%
from sklearn.model_selection import train_test_split


X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=0.3, random_state=123, stratify=y)

X_train, X_valid, y_train, y_valid = train_test_split(
    X_temp, y_temp, test_size=0.3, random_state=123, stratify=y_temp)

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# optional to free up some memory by deleting non-used arrays:
del X, y
# Out:
# (34300, 784) (34300,) (21000, 784) (21000,)

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## Implementing a single hidden-layer neural network

# %%
def sigmoid(z):
    return 1. / (1. + np.exp(-z))


def int_to_onehot(y, num_labels):

    ary = np.zeros((y.shape[0], num_labels))
    for i, val in enumerate(y):
        ary[i, val] = 1

    return ary

class NeuralNetMLP_1h:

    def __init__(self, num_features, num_hidden, num_classes, random_seed=123):
        super().__init__()

        self.num_classes = num_classes

        # hidden
        rng = np.random.RandomState(random_seed)

        self.weight_h = rng.normal(
            loc=0.0, scale=0.1, size=(num_hidden, num_features))
        self.bias_h = np.zeros(num_hidden)

        # output
        self.weight_out = rng.normal(
            loc=0.0, scale=0.1, size=(num_classes, num_hidden))
        self.bias_out = np.zeros(num_classes)

    def forward(self, x):
        # Hidden layer
        # input dim: [n_examples, n_features] dot [n_hidden, n_features].T
        # output dim: [n_examples, n_hidden]
        z_h = np.dot(x, self.weight_h.T) + self.bias_h
        a_h = sigmoid(z_h)

        # Output layer
        # input dim: [n_examples, n_hidden] dot [n_classes, n_hidden].T
        # output dim: [n_examples, n_classes]
        z_out = np.dot(a_h, self.weight_out.T) + self.bias_out
        a_out = sigmoid(z_out)
        return a_h, a_out

    def backward(self, x, a_h, a_out, y):

        #########################
        ### Output layer weights
        #########################

        # onehot encoding
        y_onehot = int_to_onehot(y, self.num_classes)

        # Part 1: dLoss/dOutWeights
        ## = dLoss/dOutAct * dOutAct/dOutNet * dOutNet/dOutWeight
        ## where DeltaOut = dLoss/dOutAct * dOutAct/dOutNet
        ## for convenient re-use

        # input/output dim: [n_examples, n_classes]
        d_loss__d_a_out = 2.*(a_out - y_onehot) / y.shape[0]

        # input/output dim: [n_examples, n_classes]
        d_a_out__d_z_out = a_out * (1. - a_out) # sigmoid derivative

        # output dim: [n_examples, n_classes]
        delta_out = d_loss__d_a_out * d_a_out__d_z_out # "delta (rule) placeholder"

        # gradient for output weights

        # [n_examples, n_hidden]
        d_z_out__dw_out = a_h

        # input dim: [n_classes, n_examples] dot [n_examples, n_hidden]
        # output dim: [n_classes, n_hidden]
        d_loss__dw_out = np.dot(delta_out.T, d_z_out__dw_out)
        d_loss__db_out = np.sum(delta_out, axis=0)


        #################################
        # Part 2: dLoss/dHiddenWeights
        ## = DeltaOut * dOutNet/dHiddenAct * dHiddenAct/dHiddenNet * dHiddenNet/dWeight

        # [n_classes, n_hidden]
        d_z_out__a_h = self.weight_out

        # output dim: [n_examples, n_hidden]
        d_loss__a_h = np.dot(delta_out, d_z_out__a_h)

        # [n_examples, n_hidden]
        d_a_h__d_z_h = a_h * (1. - a_h) # sigmoid derivative

        # [n_examples, n_features]
        d_z_h__d_w_h = x

        # output dim: [n_hidden, n_features]
        d_loss__d_w_h = np.dot((d_loss__a_h * d_a_h__d_z_h).T, d_z_h__d_w_h)
        d_loss__d_b_h = np.sum((d_loss__a_h * d_a_h__d_z_h), axis=0)

        return (d_loss__dw_out, d_loss__db_out,
                d_loss__d_w_h, d_loss__d_b_h)




model1 = NeuralNetMLP_1h(num_features=28*28,
                        num_hidden=50,
                        num_classes=10)

# %% [markdown]
# #### Defining functions to compute the loss and accuracy

# %%
def mse_loss(targets, probas, num_labels=10):
    onehot_targets = int_to_onehot(targets, num_labels=num_labels)
    return np.mean((onehot_targets - probas)**2)


def accuracy(targets, predicted_labels):
    return np.mean(predicted_labels == targets)


_, probas = model1.forward(X_valid)
mse = mse_loss(y_valid, probas)

predicted_labels = np.argmax(probas, axis=1)
acc = accuracy(y_valid, predicted_labels)

print(f'Initial validation MSE: {mse:.1f}')
print(f'Initial validation accuracy: {acc*100:.1f}%')
# Out:
# Initial validation MSE: 0.3
# Initial validation accuracy: 9.1%

# %%
num_epochs = 50
minibatch_size = 100

def minibatch_generator(X, y, minibatch_size):
    indices = np.arange(X.shape[0])
    np.random.shuffle(indices)

    for start_idx in range(0, indices.shape[0] - minibatch_size
                           + 1, minibatch_size):
        batch_idx = indices[start_idx:start_idx + minibatch_size]

        yield X[batch_idx], y[batch_idx]


# iterate over training epochs
for i in range(num_epochs):

    # iterate over minibatches
    minibatch_gen = minibatch_generator(
        X_train, y_train, minibatch_size)

    for X_train_mini, y_train_mini in minibatch_gen:

        break

    break

print(X_train_mini.shape)
print(y_train_mini.shape)
# Out:
# (100, 784)
# (100,)

# %%
def compute_mse_and_acc1(nnet, X, y, num_labels=10, minibatch_size=100):
    mse, correct_pred, num_examples = 0., 0, 0
    minibatch_gen = minibatch_generator(X, y, minibatch_size)

    for i, (features, targets) in enumerate(minibatch_gen):

        _, probas = nnet.forward(features)
        predicted_labels = np.argmax(probas, axis=1)

        onehot_targets = int_to_onehot(targets, num_labels=num_labels)
        loss = np.mean((onehot_targets - probas)**2)
        correct_pred += (predicted_labels == targets).sum()

        num_examples += targets.shape[0]
        mse += loss

    mse = mse/i
    acc = correct_pred/num_examples
    return mse, acc

# %% [markdown]
# training loop

# %%
def train1(model, X_train, y_train, X_valid, y_valid, num_epochs,
          learning_rate=0.1):

    epoch_loss = []
    epoch_train_acc = []
    epoch_valid_acc = []

    for e in range(num_epochs):

        # iterate over minibatches
        minibatch_gen = minibatch_generator(
            X_train, y_train, minibatch_size)

        for X_train_mini, y_train_mini in minibatch_gen:

            #### Compute outputs ####
            a_h, a_out = model.forward(X_train_mini)

            #### Compute gradients ####
            d_loss__d_w_out, d_loss__d_b_out, d_loss__d_w_h, d_loss__d_b_h = model.backward(X_train_mini, a_h, a_out, y_train_mini)

            #### Update weights ####
            model.weight_h -= learning_rate * d_loss__d_w_h
            model.bias_h -= learning_rate * d_loss__d_b_h
            model.weight_out -= learning_rate * d_loss__d_w_out
            model.bias_out -= learning_rate * d_loss__d_b_out

        #### Epoch Logging ####
        train_mse, train_acc = compute_mse_and_acc1(model, X_train, y_train)
        valid_mse, valid_acc = compute_mse_and_acc1(model, X_valid, y_valid)
        train_acc, valid_acc = train_acc*100, valid_acc*100
        epoch_train_acc.append(train_acc)
        epoch_valid_acc.append(valid_acc)
        epoch_loss.append(train_mse)
        print(f'Epoch: {e+1:03d}/{num_epochs:03d} '
              f'| Train MSE: {train_mse:.2f} '
              f'| Train Acc: {train_acc:.2f}% '
              f'| Valid Acc: {valid_acc:.2f}%')

    return epoch_loss, epoch_train_acc, epoch_valid_acc

# %%
mse, acc = compute_mse_and_acc1(model1, X_valid, y_valid)
print(f'Initial valid MSE: {mse:.1f}')
print(f'Initial valid accuracy: {acc*100:.1f}%')
# Out:
# Initial valid MSE: 0.3
# Initial valid accuracy: 9.1%

# %%
np.random.seed(123) # for the training set shuffling

epoch_loss, epoch_train_acc, epoch_valid_acc = train1(
    model1, X_train, y_train, X_valid, y_valid,
    num_epochs=50, learning_rate=0.1)
# Out:
# Epoch: 001/050 | Train MSE: 0.07 | Train Acc: 66.36% | Valid Acc: 66.87%
# Epoch: 002/050 | Train MSE: 0.04 | Train Acc: 79.87% | Valid Acc: 80.06%
# Epoch: 003/050 | Train MSE: 0.03 | Train Acc: 85.55% | Valid Acc: 85.10%
# Epoch: 004/050 | Train MSE: 0.03 | Train Acc: 87.24% | Valid Acc: 86.88%
# Epoch: 005/050 | Train MSE: 0.02 | Train Acc: 88.27% | Valid Acc: 87.95%
# Epoch: 006/050 | Train MSE: 0.02 | Train Acc: 89.08% | Valid Acc: 88.73%
# Epoch: 007/050 | Train MSE: 0.02 | Train Acc: 89.76% | Valid Acc: 89.37%
# Epoch: 008/050 | Train MSE: 0.02 | Train Acc: 90.25% | Valid Acc: 89.90%
# Epoch: 009/050 | Train MSE: 0.02 | Train Acc: 90.55% | Valid Acc: 90.18%
# Epoch: 010/050 | Train MSE: 0.02 | Train Acc: 90.89% | Valid Acc: 90.61%
# Epoch: 011/050 | Train MSE: 0.02 | Train Acc: 91.22% | Valid Acc: 90.76%
# Epoch: 012/050 | Train MSE: 0.02 | Train Acc: 91.47% | Valid Acc: 91.02%
# Epoch: 013/050 | Train MSE: 0.02 | Train Acc: 91.58% | Valid Acc: 91.05%
# Epoch: 014/050 | Train MSE: 0.01 | Train Acc: 91.76% | Valid Acc: 91.31%
# Epoch: 015/050 | Train MSE: 0.01 | Train Acc: 92.00% | Valid Acc: 91.39%
# Epoch: 016/050 | Train MSE: 0.01 | Train Acc: 92.13% | Valid Acc: 91.55%
# Epoch: 017/050 | Train MSE: 0.01 | Train Acc: 92.25% | Valid Acc: 91.66%
# Epoch: 018/050 | Train MSE: 0.01 | Train Acc: 92.34% | Valid Acc: 91.80%
# Epoch: 019/050 | Train MSE: 0.01 | Train Acc: 92.64% | Valid Acc: 91.95%
# Epoch: 020/050 | Train MSE: 0.01 | Train Acc: 92.67% | Valid Acc: 91.89%
# Epoch: 021/050 | Train MSE: 0.01 | Train Acc: 92.82% | Valid Acc: 92.14%
# Epoch: 022/050 | Train MSE: 0.01 | Train Acc: 92.98% | Valid Acc: 92.23%
# Epoch: 023/050 | Train MSE: 0.01 | Train Acc: 92.99% | Valid Acc: 92.41%
# Epoch: 024/050 | Train MSE: 0.01 | Train Acc: 93.26% | Valid Acc: 92.55%
# Epoch: 025/050 | Train MSE: 0.01 | Train Acc: 93.43% | Valid Acc: 92.50%
# Epoch: 026/050 | Train MSE: 0.01 | Train Acc: 93.42% | Valid Acc: 92.56%
# Epoch: 027/050 | Train MSE: 0.01 | Train Acc: 93.43% | Valid Acc: 92.63%
# Epoch: 028/050 | Train MSE: 0.01 | Train Acc: 93.63% | Valid Acc: 92.71%
# Epoch: 029/050 | Train MSE: 0.01 | Train Acc: 93.70% | Valid Acc: 92.80%
# Epoch: 030/050 | Train MSE: 0.01 | Train Acc: 93.82% | Valid Acc: 92.80%
# Epoch: 031/050 | Train MSE: 0.01 | Train Acc: 93.83% | Valid Acc: 92.88%
# Epoch: 032/050 | Train MSE: 0.01 | Train Acc: 93.87% | Valid Acc: 93.03%
# Epoch: 033/050 | Train MSE: 0.01 | Train Acc: 93.94% | Valid Acc: 93.03%
# Epoch: 034/050 | Train MSE: 0.01 | Train Acc: 94.03% | Valid Acc: 93.01%
# Epoch: 035/050 | Train MSE: 0.01 | Train Acc: 94.14% | Valid Acc: 93.20%
# Epoch: 036/050 | Train MSE: 0.01 | Train Acc: 94.14% | Valid Acc: 93.18%
# Epoch: 037/050 | Train MSE: 0.01 | Train Acc: 94.24% | Valid Acc: 93.22%
# Epoch: 038/050 | Train MSE: 0.01 | Train Acc: 94.22% | Valid Acc: 93.30%
# Epoch: 039/050 | Train MSE: 0.01 | Train Acc: 94.30% | Valid Acc: 93.33%
# Epoch: 040/050 | Train MSE: 0.01 | Train Acc: 94.39% | Valid Acc: 93.31%
# Epoch: 041/050 | Train MSE: 0.01 | Train Acc: 94.43% | Valid Acc: 93.41%
# Epoch: 042/050 | Train MSE: 0.01 | Train Acc: 94.49% | Valid Acc: 93.45%
# Epoch: 043/050 | Train MSE: 0.01 | Train Acc: 94.46% | Valid Acc: 93.43%
# Epoch: 044/050 | Train MSE: 0.01 | Train Acc: 94.54% | Valid Acc: 93.48%
# Epoch: 045/050 | Train MSE: 0.01 | Train Acc: 94.60% | Valid Acc: 93.63%
# Epoch: 046/050 | Train MSE: 0.01 | Train Acc: 94.69% | Valid Acc: 93.65%
# Epoch: 047/050 | Train MSE: 0.01 | Train Acc: 94.68% | Valid Acc: 93.54%
# Epoch: 048/050 | Train MSE: 0.01 | Train Acc: 94.75% | Valid Acc: 93.63%
# Epoch: 049/050 | Train MSE: 0.01 | Train Acc: 94.81% | Valid Acc: 93.71%
# Epoch: 050/050 | Train MSE: 0.01 | Train Acc: 94.91% | Valid Acc: 93.79%

# %% [markdown]
# ### Evaluating the neural network performance

# %%
plt.plot(range(len(epoch_loss)), epoch_loss)
plt.ylabel('Mean squared error')
plt.xlabel('Epoch')
#plt.savefig('figures/11_07.png', dpi=300)
plt.show()

# %%
plt.plot(range(len(epoch_train_acc)), epoch_train_acc,
         label='Training')
plt.plot(range(len(epoch_valid_acc)), epoch_valid_acc,
         label='Validation')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(loc='lower right')
plt.show()

# %%
test_mse, test_acc = compute_mse_and_acc1(model1, X_test, y_test)
print(f'Test accuracy: {test_acc*100:.2f}%')
print(f'MSE: {test_mse:.2f}')

y_pred = model1.forward(X_test)[1]
y_pred_softmax = []
for i in y_pred:
  temp = np.exp(i)/np.sum(np.exp(i))
  y_pred_softmax.append(np.exp(i)/np.sum(np.exp(i)))


num_classes = 10
y_pred_arr = np.array(y_pred_softmax)
y_test_true_arr = int_to_onehot(y_test, num_classes)

macro_auc1 = roc_auc_score(y_test_true_arr,y_pred_arr, average='macro',multi_class='ovr')

print("Macro AUC : %.4f" % macro_auc1)
# Out:
# Test accuracy: 93.85%
# MSE: 0.01
# Macro AUC : 0.9954

# %% [markdown]
# ## Extending the network to two hidden-layers

# %%
##########################
### MODEL
##########################

class NeuralNetMLP2:

    def __init__(self, num_features, num_hidden1, num_hidden2, num_classes, random_seed=123):
        super().__init__()

        self.num_classes = num_classes

        # hidden
        rng = np.random.RandomState(random_seed)

        self.weight_h1 = rng.normal(
            loc=0.0, scale=0.1, size=(num_hidden1, num_features))
        self.bias_h1 = np.zeros(num_hidden1)

        self.weight_h2 = rng.normal(
            loc=0.0, scale=0.1, size=(num_hidden2, num_hidden1))
        self.bias_h2 = np.zeros(num_hidden2)

        # output
        self.weight_out = rng.normal(
            loc=0.0, scale=0.1, size=(num_classes, num_hidden2))
        self.bias_out = np.zeros(num_classes)

    def forward(self, x):
        # Hidden layer1
        # input dim: [n_examples, n_features] dot [n_hidden1, n_features].T
        # output dim: [n_examples, n_hidden1]
        z_h1 = np.dot(x, self.weight_h1.T) + self.bias_h1
        a_h1 = sigmoid(z_h1)

        # Hidden layer2
        # input dim: [n_examples, n_hidden1] dot [n_hidden2, n_hidden1].T
        # output dim: [n_examples, n_hidden2]
        z_h2 = np.dot(a_h1, self.weight_h2.T) + self.bias_h2
        a_h2 = sigmoid(z_h2)

        # Output layer
        # input dim: [n_examples, n_hidden2] dot [n_classes, n_hidden2].T
        # output dim: [n_examples, n_classes]
        z_out = np.dot(a_h2, self.weight_out.T) + self.bias_out
        a_out = sigmoid(z_out)
        return a_h1, a_h2, a_out

    def backward(self, x, a_h1,a_h2, a_out, y):

        #########################
        ### Output layer weights
        #########################

        # onehot encoding
        y_onehot = int_to_onehot(y, self.num_classes)

        # Part 1: dLoss/dOutWeights
        ## = dLoss/dOutAct * dOutAct/dOutNet * dOutNet/dOutWeight
        ## where DeltaOut = dLoss/dOutAct * dOutAct/dOutNet
        ## for convenient re-use

        # input/output dim: [n_examples, n_classes]
        d_loss__d_a_out = 2.*(a_out - y_onehot) / y.shape[0]

        # input/output dim: [n_examples, n_classes]
        d_a_out__d_z_out = a_out * (1. - a_out) # sigmoid derivative

        # output dim: [n_examples, n_classes]
        delta_out = d_loss__d_a_out * d_a_out__d_z_out # "delta (rule) placeholder"

        # gradient for output weights

        # [n_examples, n_hidden2]
        d_z_out__dw_out = a_h2

        # input dim: [n_classes, n_examples] dot [n_examples, n_hidden2]
        # output dim: [n_classes, n_hidden2]
        d_loss__dw_out = np.dot(delta_out.T, d_z_out__dw_out)
        d_loss__db_out = np.sum(delta_out, axis=0)


        #################################
        # Part 2: dLoss/dHiddenWeights
        ## = DeltaOut * dOutNet/dHiddenAct * dHiddenAct/dHiddenNet * dHiddenNet/dWeight

      # [n_classes, n_hidden2]
        d_z_out__a_h2 = self.weight_out

        # output dim: [n_examples, n_hidden2]
        d_loss__a_h2 = np.dot(delta_out, d_z_out__a_h2)


        # [n_examples, n_hidden2]
        d_a_h2__d_z_h2 = a_h2 * (1. - a_h2) # sigmoid derivative

        # output dim: [n_examples, n_hidden2]
        delta_a_h2 = d_loss__a_h2 * d_a_h2__d_z_h2 # "delta (rule) placeholder"


        # [n_examples, n_hidden1]
        d_z_h2__d_w_h2 = a_h1

        # output dim: [n_hidden2, n_hidden1]
        d_loss__d_w_h2 = np.dot((d_loss__a_h2 * d_a_h2__d_z_h2).T, d_z_h2__d_w_h2)
        d_loss__d_b_h2 = np.sum((d_loss__a_h2 * d_a_h2__d_z_h2), axis=0)
        ##########################################

        # [n_hidden2, n_hidden1]
        d_z_h2__a_h1 = self.weight_h2

        # output dim: [n_examples, n_hidden1]
        d_loss__a_h1 = np.dot(delta_a_h2, d_z_h2__a_h1)

        # [n_examples, n_hidden1]
        d_a_h1__d_z_h1 = a_h1 * (1. - a_h1) # sigmoid derivative

        # [n_examples, n_features]
        d_z_h1__d_w_h1 = x

        # output dim: [n_hidden1, n_features]
        d_loss__d_w_h1 = np.dot((d_loss__a_h1 * d_a_h1__d_z_h1).T, d_z_h1__d_w_h1)
        d_loss__d_b_h1 = np.sum((d_loss__a_h1 * d_a_h1__d_z_h1), axis=0)

        return (d_loss__dw_out, d_loss__db_out,
                d_loss__d_w_h2, d_loss__d_b_h2,d_loss__d_w_h1, d_loss__d_b_h1)

# %%
#adjusting the loss function
def compute_mse_and_acc2(nnet, X, y, num_labels=10, minibatch_size=100):
    mse, correct_pred, num_examples = 0., 0, 0
    minibatch_gen = minibatch_generator(X, y, minibatch_size)

    for i, (features, targets) in enumerate(minibatch_gen):

        _, _, probas = nnet.forward(features)
        predicted_labels = np.argmax(probas, axis=1)

        onehot_targets = int_to_onehot(targets, num_labels=num_labels)
        loss = np.mean((onehot_targets - probas)**2)
        correct_pred += (predicted_labels == targets).sum()

        num_examples += targets.shape[0]
        mse += loss

    mse = mse/i
    acc = correct_pred/num_examples
    return mse, acc

# %%
model2 = NeuralNetMLP2(num_features=28*28,
                     num_hidden1=50, num_hidden2=50,
                     num_classes=10)

# %%
#train for a 2 hidden-layers model
def train2(model, X_train, y_train, X_valid, y_valid, num_epochs,
          learning_rate=0.1):

    epoch_loss = []
    epoch_train_acc = []
    epoch_valid_acc = []

    for e in range(num_epochs):

        # iterate over minibatches
        minibatch_gen = minibatch_generator(
            X_train, y_train, minibatch_size)

        for X_train_mini, y_train_mini in minibatch_gen:

            #### Compute outputs ####
            a_h1, a_h2, a_out = model.forward(X_train_mini)

            #### Compute gradients ####
            d_loss__d_w_out, d_loss__d_b_out, d_loss__d_w_h2, d_loss__d_b_h2, d_loss__d_w_h1, d_loss__d_b_h1 = \
                model.backward(X_train_mini, a_h1 ,a_h2, a_out, y_train_mini)

            #### Update weights ####
            model.weight_h1 -= learning_rate * d_loss__d_w_h1
            model.bias_h1 -= learning_rate * d_loss__d_b_h1
            model.weight_h2 -= learning_rate * d_loss__d_w_h2
            model.bias_h2 -= learning_rate * d_loss__d_b_h2
            model.weight_out -= learning_rate * d_loss__d_w_out
            model.bias_out -= learning_rate * d_loss__d_b_out

        #### Epoch Logging ####
        train_mse, train_acc = compute_mse_and_acc2(model, X_train, y_train)
        valid_mse, valid_acc = compute_mse_and_acc2(model, X_valid, y_valid)
        train_acc, valid_acc = train_acc*100, valid_acc*100
        epoch_train_acc.append(train_acc)
        epoch_valid_acc.append(valid_acc)
        epoch_loss.append(train_mse)
        print(f'Epoch: {e+1:03d}/{num_epochs:03d} '
              f'| Train MSE: {train_mse:.2f} '
              f'| Train Acc: {train_acc:.2f}% '
              f'| Valid Acc: {valid_acc:.2f}%')

    return epoch_loss, epoch_train_acc, epoch_valid_acc

# %%
np.random.seed(123) # for the training set shuffling

epoch_loss, epoch_train_acc, epoch_valid_acc = train2(
    model2, X_train, y_train, X_valid, y_valid,
    num_epochs=50, learning_rate=0.1)
# Out:
# Epoch: 001/050 | Train MSE: 0.09 | Train Acc: 16.77% | Valid Acc: 16.78%
# Epoch: 002/050 | Train MSE: 0.09 | Train Acc: 23.27% | Valid Acc: 23.49%
# Epoch: 003/050 | Train MSE: 0.09 | Train Acc: 25.89% | Valid Acc: 25.92%
# Epoch: 004/050 | Train MSE: 0.08 | Train Acc: 28.82% | Valid Acc: 28.67%
# Epoch: 005/050 | Train MSE: 0.07 | Train Acc: 48.91% | Valid Acc: 48.95%
# Epoch: 006/050 | Train MSE: 0.06 | Train Acc: 60.79% | Valid Acc: 60.96%
# Epoch: 007/050 | Train MSE: 0.05 | Train Acc: 64.91% | Valid Acc: 65.05%
# Epoch: 008/050 | Train MSE: 0.05 | Train Acc: 74.21% | Valid Acc: 74.50%
# Epoch: 009/050 | Train MSE: 0.04 | Train Acc: 79.70% | Valid Acc: 79.80%
# Epoch: 010/050 | Train MSE: 0.03 | Train Acc: 84.01% | Valid Acc: 84.07%
# Epoch: 011/050 | Train MSE: 0.03 | Train Acc: 86.22% | Valid Acc: 85.95%
# Epoch: 012/050 | Train MSE: 0.03 | Train Acc: 87.27% | Valid Acc: 86.90%
# Epoch: 013/050 | Train MSE: 0.02 | Train Acc: 87.92% | Valid Acc: 87.66%
# Epoch: 014/050 | Train MSE: 0.02 | Train Acc: 88.62% | Valid Acc: 88.25%
# Epoch: 015/050 | Train MSE: 0.02 | Train Acc: 89.06% | Valid Acc: 88.59%
# Epoch: 016/050 | Train MSE: 0.02 | Train Acc: 89.46% | Valid Acc: 89.13%
# Epoch: 017/050 | Train MSE: 0.02 | Train Acc: 89.88% | Valid Acc: 89.50%
# Epoch: 018/050 | Train MSE: 0.02 | Train Acc: 90.08% | Valid Acc: 89.63%
# Epoch: 019/050 | Train MSE: 0.02 | Train Acc: 90.42% | Valid Acc: 89.98%
# Epoch: 020/050 | Train MSE: 0.02 | Train Acc: 90.64% | Valid Acc: 90.07%
# Epoch: 021/050 | Train MSE: 0.02 | Train Acc: 90.92% | Valid Acc: 90.44%
# Epoch: 022/050 | Train MSE: 0.02 | Train Acc: 91.22% | Valid Acc: 90.61%
# Epoch: 023/050 | Train MSE: 0.02 | Train Acc: 91.43% | Valid Acc: 90.78%
# Epoch: 024/050 | Train MSE: 0.01 | Train Acc: 91.69% | Valid Acc: 90.92%
# Epoch: 025/050 | Train MSE: 0.01 | Train Acc: 91.83% | Valid Acc: 91.12%
# Epoch: 026/050 | Train MSE: 0.01 | Train Acc: 92.01% | Valid Acc: 91.22%
# Epoch: 027/050 | Train MSE: 0.01 | Train Acc: 92.08% | Valid Acc: 91.31%
# Epoch: 028/050 | Train MSE: 0.01 | Train Acc: 92.32% | Valid Acc: 91.58%
# Epoch: 029/050 | Train MSE: 0.01 | Train Acc: 92.47% | Valid Acc: 91.70%
# Epoch: 030/050 | Train MSE: 0.01 | Train Acc: 92.59% | Valid Acc: 91.83%
# Epoch: 031/050 | Train MSE: 0.01 | Train Acc: 92.75% | Valid Acc: 91.92%
# Epoch: 032/050 | Train MSE: 0.01 | Train Acc: 92.86% | Valid Acc: 92.04%
# Epoch: 033/050 | Train MSE: 0.01 | Train Acc: 92.92% | Valid Acc: 92.18%
# Epoch: 034/050 | Train MSE: 0.01 | Train Acc: 93.15% | Valid Acc: 92.26%
# Epoch: 035/050 | Train MSE: 0.01 | Train Acc: 93.23% | Valid Acc: 92.37%
# Epoch: 036/050 | Train MSE: 0.01 | Train Acc: 93.39% | Valid Acc: 92.38%
# Epoch: 037/050 | Train MSE: 0.01 | Train Acc: 93.49% | Valid Acc: 92.60%
# Epoch: 038/050 | Train MSE: 0.01 | Train Acc: 93.61% | Valid Acc: 92.56%
# Epoch: 039/050 | Train MSE: 0.01 | Train Acc: 93.73% | Valid Acc: 92.69%
# Epoch: 040/050 | Train MSE: 0.01 | Train Acc: 93.90% | Valid Acc: 92.82%
# Epoch: 041/050 | Train MSE: 0.01 | Train Acc: 93.93% | Valid Acc: 92.78%
# Epoch: 042/050 | Train MSE: 0.01 | Train Acc: 94.04% | Valid Acc: 92.90%
# Epoch: 043/050 | Train MSE: 0.01 | Train Acc: 94.13% | Valid Acc: 93.04%
# Epoch: 044/050 | Train MSE: 0.01 | Train Acc: 94.21% | Valid Acc: 93.10%
# Epoch: 045/050 | Train MSE: 0.01 | Train Acc: 94.31% | Valid Acc: 93.14%
# Epoch: 046/050 | Train MSE: 0.01 | Train Acc: 94.40% | Valid Acc: 93.27%
# Epoch: 047/050 | Train MSE: 0.01 | Train Acc: 94.41% | Valid Acc: 93.27%
# Epoch: 048/050 | Train MSE: 0.01 | Train Acc: 94.41% | Valid Acc: 93.24%
# Epoch: 049/050 | Train MSE: 0.01 | Train Acc: 94.61% | Valid Acc: 93.37%
# Epoch: 050/050 | Train MSE: 0.01 | Train Acc: 94.64% | Valid Acc: 93.49%

# %% [markdown]
# ## Evaluating the neural network performance

# %%
plt.plot(range(len(epoch_loss)), epoch_loss)
plt.ylabel('Mean squared error')
plt.xlabel('Epoch')
plt.show()

# %%
plt.plot(range(len(epoch_train_acc)), epoch_train_acc,
         label='Training')
plt.plot(range(len(epoch_valid_acc)), epoch_valid_acc,
         label='Validation')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(loc='lower right')
plt.show()

# %%
test_mse, test_acc = compute_mse_and_acc2(model2, X_test, y_test)
print(f'Test accuracy: {test_acc*100:.2f}%')
print(f'MSE: {test_mse:.2f}')

y_pred = model2.forward(X_test)[2]
y_pred[0].shape
y_pred_softmax = []
for i in y_pred:
  temp = np.exp(i)/np.sum(np.exp(i))
  y_pred_softmax.append(temp)

num_classes = 10
y_pred_arr = np.array(y_pred_softmax)
y_test_true_arr = int_to_onehot(y_test, num_classes)

macro_auc = roc_auc_score(y_test_true_arr,y_pred_arr, average='macro',multi_class='ovr')

print("Macro AUC: %.4f" % macro_auc)
# Out:
# Test accuracy: 93.54%
# MSE: 0.01
# Macro AUC: 0.9952

# %% [markdown]
# Plot failure cases:

# %%
X_test_subset = X_test[:1000, :]
y_test_subset = y_test[:1000]

_, _, probas = model2.forward(X_test_subset)
test_pred = np.argmax(probas, axis=1)

misclassified_images = X_test_subset[y_test_subset != test_pred][:25]
misclassified_labels = test_pred[y_test_subset != test_pred][:25]
correct_labels = y_test_subset[y_test_subset != test_pred][:25]

# %%
fig, ax = plt.subplots(nrows=5, ncols=5,
                       sharex=True, sharey=True, figsize=(8, 8))
ax = ax.flatten()
for i in range(25):
    img = misclassified_images[i].reshape(28, 28)
    ax[i].imshow(img, cmap='Greys', interpolation='nearest')
    ax[i].set_title(f'{i+1}) '
                    f'True: {correct_labels[i]}\n'
                    f' Predicted: {misclassified_labels[i]}')

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
#plt.savefig('figures/11_09.png', dpi=300)
plt.show()

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# # KERAS implementation

# %%
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
print(X_train.mean(),X_train.std())
print(X_train.dtype)
# Out:
# (34300, 784) (34300,) (21000, 784) (21000,)
# -0.7384513435111643 0.6165026061827255
# float64

# %%
from keras.utils import np_utils

#Preprocessing
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
X_valid = X_valid.reshape(X_valid.shape[0], 28, 28, 1).astype('float32')
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32')
y_train = np_utils.to_categorical(y_train)
y_valid = np_utils.to_categorical(y_valid)
y_test = np_utils.to_categorical(y_test)
num_classes = y_test.shape[1]

print(X_train.shape, y_train.shape, X_valid.shape, y_valid.shape, X_test.shape, y_test.shape)
# Out:
# (34300, 28, 28, 1) (34300, 10) (14700, 28, 28, 1) (14700, 10) (21000, 28, 28, 1) (21000, 10)

# %% [markdown]
# #Keras  Implementation 1 :  according to lecture guidelines

# %% [markdown]
# ![WhatsApp Image 2023-06-18 at 21.44.27.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-06-18 at 21.45.37.jpg](data:image/jpeg;base64,...)

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten
from sklearn.metrics import roc_auc_score
from keras.optimizers import SGD
import numpy as np
np.random.RandomState(4242)

# Create the model
model3 = Sequential()
model3.add(Flatten(input_shape=(28, 28,1))) # must be added so the dims are correct

model3.add(Dense(units=500,  activation='sigmoid'))

model3.add(Dense(units=500, activation='sigmoid'))

model3.add(Dense(units=10, activation='softmax'))

# Compile the model
model3.compile(loss='mse', optimizer=SGD(learning_rate=0.1), metrics=['accuracy'])

# Train the model
history = model3.fit(X_train, y_train, validation_data = (X_valid, y_valid), epochs=20, batch_size=100)

# Evaluate the model on the test data
scores = model3.evaluate(X_test, y_test)
print('\n\nTotal loss on training set: ' + str(scores[0]) +'\nAccuracy on test set ' + str(scores[1]))

y_pred = model3.predict(X_test)
auc_scores = []
for i in range(10):
    auc = roc_auc_score(y_test[:, i], y_pred[:, i])
    auc_scores.append(auc)

macro_auc = np.mean(auc_scores)
print("Macro AUC: %.4f" % macro_auc)
# Out:
# Epoch 1/20
# 343/343 [==============================] - 2s 4ms/step - loss: 0.0898 - accuracy: 0.1376 - val_loss: 0.0893 - val_accuracy: 0.2069
# Epoch 2/20
# 343/343 [==============================] - 1s 3ms/step - loss: 0.0889 - accuracy: 0.2139 - val_loss: 0.0885 - val_accuracy: 0.2468
# Epoch 3/20
# 343/343 [==============================] - 1s 3ms/step - loss: 0.0881 - accuracy: 0.2817 - val_loss: 0.0877 - val_accuracy: 0.2291
# Epoch 4/20
# 343/343 [==============================] - 1s 3ms/step - loss: 0.0872 - accuracy: 0.3044 - val_loss: 0.0867 - val_accuracy: 0.3385
# Epoch 5/20
# 343/343 [==============================] - 1s 3ms/step - loss: 0.0861 - accuracy: 0.3301 - val_loss: 0.0854 - val_accuracy: 0.3191
# Epoch 6/20
# 343/343 [==============================] - 1s 3ms/step - loss: 0.0847 - accuracy: 0.3413 - val_loss: 0.0838 - val_accuracy: 0.3216
# Epoch 7/20
# 343/343 [==============================] - 1s 3ms/step - loss: 0.0828 - accuracy: 0.3587 - val_loss: 0.0817 - val_accuracy: 0.4207
# Epoch 8/20
# 343/343 [==============================] - 1s 3ms/step - loss: 0.0805 - accuracy: 0.3942 - val_loss: 0.0790 - val_accuracy: 0.3983
# Epoch 9/20
# 343/343 [==============================] - 1s 3ms/step - loss: 0.0777 - accuracy: 0.4331 - val_loss: 0.0760 - val_accuracy: 0.4730
# Epoch 10/20
# 343/343 [==============================] - 1s 3ms/step - loss: 0.0745 - accuracy: 0.4791 - val_loss: 0.0727 - val_accuracy: 0.4792
# Epoch 11/20
# 343/343 [==============================] - 1s 3ms/step - loss: 0.0711 - accuracy: 0.5117 - val_loss: 0.0691 - val_accuracy: 0.5263
# Epoch 12/20
# 343/343 [==============================] - 1s 3ms/step - loss: 0.0674 - accuracy: 0.5439 - val_loss: 0.0653 - val_accuracy: 0.5569
# Epoch 13/20
# 343/343 [==============================] - 1s 3ms/step - loss: 0.0637 - accuracy: 0.5743 - val_loss: 0.0615 - val_accuracy: 0.5935
# Epoch 14/20
# 343/343 [==============================] - 1s 3ms/step - loss: 0.0599 - accuracy: 0.6060 - val_loss: 0.0577 - val_accuracy: 0.6310
# Epoch 15/20
# 343/343 [==============================] - 1s 3ms/step - loss: 0.0562 - accuracy: 0.6335 - val_loss: 0.0541 - val_accuracy: 0.6563
# Epoch 16/20
# 343/343 [==============================] - 1s 3ms/step - loss: 0.0526 - accuracy: 0.6641 - val_loss: 0.0506 - val_accuracy: 0.6714
# Epoch 17/20
# 343/343 [==============================] - 1s 3ms/step - loss: 0.0493 - accuracy: 0.6933 - val_loss: 0.0474 - val_accuracy: 0.7152
# Epoch 18/20
# 343/343 [==============================] - 1s 3ms/step - loss: 0.0462 - accuracy: 0.7260 - val_loss: 0.0444 - val_accuracy: 0.7439
# Epoch 19/20
# 343/343 [==============================] - 1s 3ms/step - loss: 0.0433 - accuracy: 0.7555 - val_loss: 0.0417 - val_accuracy: 0.7589
# Epoch 20/20
# 343/343 [==============================] - 1s 3ms/step - loss: 0.0406 - accuracy: 0.7812 - val_loss: 0.0391 - val_accuracy: 0.7929
# 657/657 [==============================] - 1s 2ms/step - loss: 0.0394 - accuracy: 0.7932
#
#
# Total loss on training set: 0.0394221656024456
# Accuracy on test set 0.79323810338974
# 657/657 [==============================] - 1s 2ms/step
# Macro AUC: 0.9764

# %%
# Plot the training and validation loss
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curves')
plt.legend()

# Plot the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy Curves')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Keras implementation 2 : a better one
# ## similar to our 2 hidden layers 50 units,  50 epochs, but with Adam Optimizer

# %%
from keras.optimizers import Adam
# Create the model
model4 = Sequential()
model4.add(Flatten(input_shape=(28, 28, 1)))
model4.add(Dense(50, activation='sigmoid'))
model4.add(Dense(50, activation='sigmoid'))
model4.add(Dense(num_classes, activation='softmax'))

model4.summary()

# Compile the model
model4.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy','mse'])

# Train the model
history=model4.fit(X_train, y_train, validation_data=(X_valid, y_valid), epochs=50, batch_size=100, verbose=2)

# Evaluate the model on the test data
scores = model4.evaluate(X_test, y_test)
print('\n\nTotal loss on training set: ' + str(scores[0]) +'\nAccuracy on test set ' + str(scores[1]))

y_pred = model4.predict(X_test)
auc_scores = []
for i in range(num_classes):
    auc = roc_auc_score(y_test[:, i], y_pred[:, i])
    auc_scores.append(auc)

macro_auc = np.mean(auc_scores)
print("Macro AUC: %.4f" % macro_auc)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_6 (Dense)             (None, 50)                39250
#
#  dense_7 (Dense)             (None, 50)                2550
#
#  dense_8 (Dense)             (None, 10)                510
#
# =================================================================
# Total params: 42,310
# Trainable params: 42,310
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 343/343 - 4s - loss: 0.0489 - accuracy: 0.7044 - mse: 0.0489 - val_loss: 0.0208 - val_accuracy: 0.8835 - val_mse: 0.0208 - 4s/epoch - 11ms/step
# Epoch 2/50
# 343/343 - 1s - loss: 0.0164 - accuracy: 0.9028 - mse: 0.0164 - val_loss: 0.0143 - val_accuracy: 0.9108 - val_mse: 0.0143 - 1s/epoch - 3ms/step
# Epoch 3/50
# 343/343 - 1s - loss: 0.0125 - accuracy: 0.9226 - mse: 0.0125 - val_loss: 0.0118 - val_accuracy: 0.9233 - val_mse: 0.0118 - 1s/epoch - 3ms/step
# Epoch 4/50
# 343/343 - 1s - loss: 0.0105 - accuracy: 0.9359 - mse: 0.0105 - val_loss: 0.0102 - val_accuracy: 0.9338 - val_mse: 0.0102 - 1s/epoch - 3ms/step
# Epoch 5/50
# 343/343 - 1s - loss: 0.0092 - accuracy: 0.9439 - mse: 0.0092 - val_loss: 0.0095 - val_accuracy: 0.9395 - val_mse: 0.0095 - 1s/epoch - 3ms/step
# Epoch 6/50
# 343/343 - 1s - loss: 0.0082 - accuracy: 0.9496 - mse: 0.0082 - val_loss: 0.0091 - val_accuracy: 0.9408 - val_mse: 0.0091 - 1s/epoch - 3ms/step
# Epoch 7/50
# 343/343 - 1s - loss: 0.0076 - accuracy: 0.9543 - mse: 0.0076 - val_loss: 0.0085 - val_accuracy: 0.9452 - val_mse: 0.0085 - 1s/epoch - 3ms/step
# Epoch 8/50
# 343/343 - 1s - loss: 0.0068 - accuracy: 0.9594 - mse: 0.0068 - val_loss: 0.0080 - val_accuracy: 0.9486 - val_mse: 0.0080 - 1s/epoch - 3ms/step
# Epoch 9/50
# 343/343 - 1s - loss: 0.0062 - accuracy: 0.9633 - mse: 0.0062 - val_loss: 0.0076 - val_accuracy: 0.9499 - val_mse: 0.0076 - 1s/epoch - 3ms/step
# Epoch 10/50
# 343/343 - 1s - loss: 0.0057 - accuracy: 0.9659 - mse: 0.0057 - val_loss: 0.0073 - val_accuracy: 0.9530 - val_mse: 0.0073 - 1s/epoch - 3ms/step
# Epoch 11/50
# 343/343 - 1s - loss: 0.0054 - accuracy: 0.9686 - mse: 0.0054 - val_loss: 0.0070 - val_accuracy: 0.9545 - val_mse: 0.0070 - 1s/epoch - 3ms/step
# Epoch 12/50
# 343/343 - 1s - loss: 0.0050 - accuracy: 0.9715 - mse: 0.0050 - val_loss: 0.0069 - val_accuracy: 0.9544 - val_mse: 0.0069 - 1s/epoch - 3ms/step
# Epoch 13/50
# 343/343 - 1s - loss: 0.0047 - accuracy: 0.9727 - mse: 0.0047 - val_loss: 0.0067 - val_accuracy: 0.9548 - val_mse: 0.0067 - 1s/epoch - 3ms/step
# Epoch 14/50
# 343/343 - 1s - loss: 0.0044 - accuracy: 0.9743 - mse: 0.0044 - val_loss: 0.0064 - val_accuracy: 0.9592 - val_mse: 0.0064 - 1s/epoch - 3ms/step
# Epoch 15/50
# 343/343 - 1s - loss: 0.0041 - accuracy: 0.9764 - mse: 0.0041 - val_loss: 0.0064 - val_accuracy: 0.9582 - val_mse: 0.0064 - 1s/epoch - 3ms/step
# Epoch 16/50
# 343/343 - 1s - loss: 0.0040 - accuracy: 0.9769 - mse: 0.0040 - val_loss: 0.0062 - val_accuracy: 0.9588 - val_mse: 0.0062 - 1s/epoch - 3ms/step
# Epoch 17/50
# 343/343 - 1s - loss: 0.0037 - accuracy: 0.9788 - mse: 0.0037 - val_loss: 0.0063 - val_accuracy: 0.9592 - val_mse: 0.0063 - 1s/epoch - 3ms/step
# Epoch 18/50
# 343/343 - 1s - loss: 0.0035 - accuracy: 0.9797 - mse: 0.0035 - val_loss: 0.0064 - val_accuracy: 0.9582 - val_mse: 0.0064 - 1s/epoch - 3ms/step
# Epoch 19/50
# 343/343 - 1s - loss: 0.0034 - accuracy: 0.9801 - mse: 0.0034 - val_loss: 0.0060 - val_accuracy: 0.9607 - val_mse: 0.0060 - 1s/epoch - 3ms/step
# Epoch 20/50
# 343/343 - 1s - loss: 0.0032 - accuracy: 0.9821 - mse: 0.0032 - val_loss: 0.0063 - val_accuracy: 0.9587 - val_mse: 0.0063 - 1s/epoch - 3ms/step
# Epoch 21/50
# 343/343 - 1s - loss: 0.0030 - accuracy: 0.9832 - mse: 0.0030 - val_loss: 0.0056 - val_accuracy: 0.9631 - val_mse: 0.0056 - 1s/epoch - 3ms/step
# Epoch 22/50
# 343/343 - 1s - loss: 0.0029 - accuracy: 0.9838 - mse: 0.0029 - val_loss: 0.0061 - val_accuracy: 0.9603 - val_mse: 0.0061 - 1s/epoch - 3ms/step
# Epoch 23/50
# 343/343 - 1s - loss: 0.0028 - accuracy: 0.9846 - mse: 0.0028 - val_loss: 0.0059 - val_accuracy: 0.9605 - val_mse: 0.0059 - 1s/epoch - 3ms/step
# Epoch 24/50
# 343/343 - 1s - loss: 0.0026 - accuracy: 0.9862 - mse: 0.0026 - val_loss: 0.0059 - val_accuracy: 0.9603 - val_mse: 0.0059 - 1s/epoch - 3ms/step
# Epoch 25/50
# 343/343 - 1s - loss: 0.0026 - accuracy: 0.9857 - mse: 0.0026 - val_loss: 0.0063 - val_accuracy: 0.9589 - val_mse: 0.0063 - 1s/epoch - 3ms/step
# Epoch 26/50
# 343/343 - 1s - loss: 0.0024 - accuracy: 0.9865 - mse: 0.0024 - val_loss: 0.0056 - val_accuracy: 0.9639 - val_mse: 0.0056 - 1s/epoch - 3ms/step
# Epoch 27/50
# 343/343 - 1s - loss: 0.0022 - accuracy: 0.9875 - mse: 0.0022 - val_loss: 0.0057 - val_accuracy: 0.9633 - val_mse: 0.0057 - 1s/epoch - 3ms/step
# Epoch 28/50
# 343/343 - 1s - loss: 0.0022 - accuracy: 0.9875 - mse: 0.0022 - val_loss: 0.0060 - val_accuracy: 0.9600 - val_mse: 0.0060 - 1s/epoch - 3ms/step
# Epoch 29/50
# 343/343 - 1s - loss: 0.0022 - accuracy: 0.9880 - mse: 0.0022 - val_loss: 0.0056 - val_accuracy: 0.9637 - val_mse: 0.0056 - 1s/epoch - 3ms/step
# Epoch 30/50
# 343/343 - 1s - loss: 0.0021 - accuracy: 0.9885 - mse: 0.0021 - val_loss: 0.0057 - val_accuracy: 0.9623 - val_mse: 0.0057 - 1s/epoch - 3ms/step
# Epoch 31/50
# 343/343 - 1s - loss: 0.0019 - accuracy: 0.9897 - mse: 0.0019 - val_loss: 0.0054 - val_accuracy: 0.9648 - val_mse: 0.0054 - 1s/epoch - 3ms/step
# Epoch 32/50
# 343/343 - 1s - loss: 0.0020 - accuracy: 0.9892 - mse: 0.0020 - val_loss: 0.0061 - val_accuracy: 0.9598 - val_mse: 0.0061 - 1s/epoch - 3ms/step
# Epoch 33/50
# 343/343 - 1s - loss: 0.0020 - accuracy: 0.9890 - mse: 0.0020 - val_loss: 0.0056 - val_accuracy: 0.9646 - val_mse: 0.0056 - 1s/epoch - 3ms/step
# Epoch 34/50
# 343/343 - 1s - loss: 0.0018 - accuracy: 0.9905 - mse: 0.0018 - val_loss: 0.0056 - val_accuracy: 0.9644 - val_mse: 0.0056 - 1s/epoch - 3ms/step
# Epoch 35/50
# 343/343 - 1s - loss: 0.0016 - accuracy: 0.9915 - mse: 0.0016 - val_loss: 0.0054 - val_accuracy: 0.9652 - val_mse: 0.0054 - 1s/epoch - 3ms/step
# Epoch 36/50
# 343/343 - 1s - loss: 0.0016 - accuracy: 0.9914 - mse: 0.0016 - val_loss: 0.0060 - val_accuracy: 0.9613 - val_mse: 0.0060 - 1s/epoch - 3ms/step
# Epoch 37/50
# 343/343 - 1s - loss: 0.0016 - accuracy: 0.9911 - mse: 0.0016 - val_loss: 0.0056 - val_accuracy: 0.9635 - val_mse: 0.0056 - 1s/epoch - 3ms/step
# Epoch 38/50
# 343/343 - 1s - loss: 0.0016 - accuracy: 0.9918 - mse: 0.0016 - val_loss: 0.0059 - val_accuracy: 0.9606 - val_mse: 0.0059 - 1s/epoch - 3ms/step
# Epoch 39/50
# 343/343 - 1s - loss: 0.0017 - accuracy: 0.9910 - mse: 0.0017 - val_loss: 0.0058 - val_accuracy: 0.9619 - val_mse: 0.0058 - 1s/epoch - 3ms/step
# Epoch 40/50
# 343/343 - 1s - loss: 0.0014 - accuracy: 0.9930 - mse: 0.0014 - val_loss: 0.0057 - val_accuracy: 0.9620 - val_mse: 0.0057 - 1s/epoch - 3ms/step
# Epoch 41/50
# 343/343 - 1s - loss: 0.0014 - accuracy: 0.9924 - mse: 0.0014 - val_loss: 0.0061 - val_accuracy: 0.9604 - val_mse: 0.0061 - 1s/epoch - 3ms/step
# Epoch 42/50
# 343/343 - 1s - loss: 0.0013 - accuracy: 0.9931 - mse: 0.0013 - val_loss: 0.0064 - val_accuracy: 0.9578 - val_mse: 0.0064 - 1s/epoch - 3ms/step
# Epoch 43/50
# 343/343 - 1s - loss: 0.0017 - accuracy: 0.9907 - mse: 0.0017 - val_loss: 0.0055 - val_accuracy: 0.9633 - val_mse: 0.0055 - 1s/epoch - 3ms/step
# Epoch 44/50
# 343/343 - 1s - loss: 0.0012 - accuracy: 0.9936 - mse: 0.0012 - val_loss: 0.0055 - val_accuracy: 0.9655 - val_mse: 0.0055 - 1s/epoch - 3ms/step
# Epoch 45/50
# 343/343 - 1s - loss: 0.0012 - accuracy: 0.9938 - mse: 0.0012 - val_loss: 0.0064 - val_accuracy: 0.9587 - val_mse: 0.0064 - 1s/epoch - 3ms/step
# Epoch 46/50
# 343/343 - 1s - loss: 0.0013 - accuracy: 0.9933 - mse: 0.0013 - val_loss: 0.0057 - val_accuracy: 0.9633 - val_mse: 0.0057 - 1s/epoch - 3ms/step
# Epoch 47/50
# 343/343 - 1s - loss: 0.0013 - accuracy: 0.9934 - mse: 0.0013 - val_loss: 0.0058 - val_accuracy: 0.9632 - val_mse: 0.0058 - 1s/epoch - 3ms/step
# Epoch 48/50
# 343/343 - 1s - loss: 0.0014 - accuracy: 0.9924 - mse: 0.0014 - val_loss: 0.0057 - val_accuracy: 0.9631 - val_mse: 0.0057 - 1s/epoch - 3ms/step
# Epoch 49/50
# 343/343 - 1s - loss: 0.0011 - accuracy: 0.9941 - mse: 0.0011 - val_loss: 0.0057 - val_accuracy: 0.9638 - val_mse: 0.0057 - 1s/epoch - 3ms/step
# Epoch 50/50
# 343/343 - 1s - loss: 0.0011 - accuracy: 0.9944 - mse: 0.0011 - val_loss: 0.0056 - val_accuracy: 0.9646 - val_mse: 0.0056 - 1s/epoch - 3ms/step
# 657/657 [==============================] - 2s 2ms/step - loss: 0.0059 - accuracy: 0.9631 - mse: 0.0059
#
#
# Total loss on training set: 0.005879234056919813
# Accuracy on test set 0.9630952477455139
# 657/657 [==============================] - 1s 1ms/step
# Macro AUC: 0.9984

# %%
# Plot the training and validation loss
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curves')
plt.legend()

# Plot the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy Curves')
plt.legend()

plt.tight_layout()
plt.show()
